# %%
import os
import numpy as np
import pandas as pd

# %%
results = []
results_dir = '/home/thompsjame1/testing/logs/eval3'

for filename in os.listdir(results_dir):
    if not filename.endswith('.npz'):
        continue

    model = filename.split('_')[0]
    env = filename.split('_')[1]
    steps = filename.split('_')[2]
    seed = filename.split('_')[3].split('.')[0]
    npz = np.load(os.path.join(results_dir, filename))

    results.append({
        'model': model,
        'env': env,
        'total_steps': steps,
        'seed': seed,
        'timesteps': npz['timesteps'],
        'rewards': npz['results'],
        'ep_lengths': npz['ep_lengths'],
    })

df = pd.DataFrame(results)

df.explode(['timesteps', 'rewards', 'ep_lengths'])
# Out:
#   model                        env total_steps seed timesteps  \
# 0   ppo  InvertedDoublePendulum-v5         200    2       100
# 0   ppo  InvertedDoublePendulum-v5         200    2       200
# 1   ppo                Walker2d-v5         200    2       100
# 1   ppo                Walker2d-v5         200    2       200
# 2   ppo                Humanoid-v5         200    2       100
# 2   ppo                Humanoid-v5         200    2       200
# 3   ppo                  Hopper-v5         200    2       100
# 3   ppo                  Hopper-v5         200    2       200
# 4   ppo                  Pusher-v5         200    2       100
# 4   ppo                  Pusher-v5         200    2       200
# 5   ppo                 Swimmer-v5         200    2       100
# 5   ppo                 Swimmer-v5         200    2       200
# 6   ppo             HalfCheetah-v5         200    2       100
# 6   ppo             HalfCheetah-v5         200    2       200
# 7   ppo                     Ant-v5         200    2       100
# 7   ppo                     Ant-v5         200    2       200
# 8   ppo         HumanoidStandup-v5         200    2       100
# 8   ppo         HumanoidStandup-v5         200    2       200
#
#                                              rewards  \
# 0  [63.383166, 91.399314, 72.127245, 81.618311, 7...
# 0  [63.141038, 44.801286, 53.720622, 44.604399, 4...
# 1  [-5.869645, -5.780449, -6.244476, -6.25968, -5...
# 1  [71.32238, 65.482556, 65.706215, 62.966342, 70...
# 2  [131.555731, 132.374396, 134.665328, 127.55139...
# 2  [156.778801, 145.920547, 157.158431, 152.29548...
# 3  [56.562996, 54.82491, 54.243737, 54.753029, 54...
# 3  [14.987607, 15.547329, 15.212524, 15.053078, 1...
# 4  [-52.32914, -49.541, -55.679643, -55.215701, -...
# 4  [-62.01327, -54.100811, -58.257311, -58.87077,...
# 5  [-21.989191, -34.549125, -6.019909, -4.106072,...
# 5  [-21.483196, -20.948169, -8.560739, -14.724804...
# 6  [-3.412508, -2.2897, -2.101951, -2.10616, -2.1...
# 6  [-0.814476, -0.972061, -1.312191, -0.117438, -...
# 7  [973.766875, 979.815172, 977.073515, 980.49142...
# 7  [988.455743, 994.978455, 998.136567, 981.40774...
# 8  [39818.874831, 51256.453052, 59206.237468, 415...
# 8  [33324.872156, 33103.471177, 30166.296865, 318...
#
#                                           ep_lengths
# 0                  [8, 11, 9, 10, 9, 9, 8, 9, 11, 8]
# 0                     [8, 6, 7, 6, 6, 6, 6, 6, 6, 6]
# 1           [23, 22, 22, 23, 22, 22, 22, 23, 23, 22]
# 1           [79, 75, 77, 75, 77, 77, 80, 76, 72, 81]
# 2           [27, 27, 27, 26, 27, 27, 25, 27, 27, 27]
# 2           [34, 31, 34, 32, 36, 35, 31, 35, 28, 35]
# 3           [47, 46, 46, 46, 46, 46, 46, 47, 46, 46]
# 3           [24, 25, 24, 24, 24, 24, 25, 25, 24, 24]
# 4  [100, 100, 100, 100, 100, 100, 100, 100, 100, ...
# 4  [100, 100, 100, 100, 100, 100, 100, 100, 100, ...
# 5  [1000, 1000, 1000, 1000, 1000, 1000, 1000, 100...
# 5  [1000, 1000, 1000, 1000, 1000, 1000, 1000, 100...
# 6  [1000, 1000, 1000, 1000, 1000, 1000, 1000, 100...
# 6  [1000, 1000, 1000, 1000, 1000, 1000, 1000, 100...
# 7  [1000, 1000, 1000, 1000, 1000, 1000, 1000, 100...
# 7  [1000, 1000, 1000, 1000, 1000, 1000, 1000, 100...
# 8  [1000, 1000, 1000, 1000, 1000, 1000, 1000, 100...
# 8  [1000, 1000, 1000, 1000, 1000, 1000, 1000, 100...
